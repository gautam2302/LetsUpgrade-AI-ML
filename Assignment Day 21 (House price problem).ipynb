# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset=pd.read_excel("Linear Regression.xlsx",sheet_name=0)
dataset.head()
# Out:
#     price  sqft_living  bedrooms  bathrooms  floors
# 0  221900         1180         3       1.00     1.0
# 1  538000         2570         3       2.25     2.0
# 2  180000          770         2       1.00     1.0
# 3  604000         1960         4       3.00     1.0
# 4  510000         1680         3       2.00     1.0

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        21613 non-null  int64
#  1   sqft_living  21613 non-null  int64
#  2   bedrooms     21613 non-null  int64
#  3   bathrooms    21613 non-null  float64
#  4   floors       21613 non-null  float64
# dtypes: float64(2), int64(3)
# memory usage: 844.4 KB

# %% [raw]
# ## Plotting Pairplot

# %%
sns.pairplot(dataset)

# %% [raw]
# ## Plotting boxplot for various variables

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.boxplot(dataset['price'],ax=ax)

# %%
fig, ax = plt.subplots(figsize=(6,6))
sns.boxplot(dataset['sqft_living'])

# %%
sns.boxplot(dataset['bedrooms'])

# %%
sns.boxplot(dataset['bathrooms'])

# %%
sns.boxplot(dataset['floors'])

# %% [raw]
# ## Plotting Histogram for various variables

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.distplot(dataset.price,ax=ax)

# %%
fig, ax = plt.subplots(figsize=(6,6))
sns.distplot(dataset.sqft_living,ax=ax)

# %%
fig, ax = plt.subplots(figsize=(6,6))
sns.distplot(dataset.bedrooms,ax=ax)

# %%
fig, ax = plt.subplots(figsize=(6,6))
sns.distplot(dataset.bathrooms,ax=ax)

# %%
fig, ax = plt.subplots(figsize=(6,6))
sns.distplot(dataset.floors,ax=ax)

# %% [raw]
# ## Data Visualization Inferences:--
#
# A) The dependent variable price is unimodal,left skewed and has many outliers.
#
# B) The independent variable area of living in square feet is unimodal,left skewed and has many outliers.
#
# C) The independent variable -- number of bedrooms & number of bathrooms -- are multimodal and has moderate outliers.
#
# D) The independent variable number of floors is multimodal and has no outliers.

# %% [raw]
# ## Printing Heatmap of the dataset

# %%
sns.heatmap(dataset.corr(),annot=True,cmap='coolwarm')

# %% [raw]
# ## Correlation Inferences
#
# The target variable price has good correlation with area of living in square feet and moderate correlation with number of bathrooms and bedrooms and almost no correlation with number of floors.

# %% [raw]
# ## Making Model 1

# %% [raw]
# ## Price as dependent variable and area of living in square feet as independent variable. Since both the variables are
#    continuous a simple linear regression model is used.

# %% [raw]
# ##  Splitting the dataset into training and testing data

# %%
y=dataset.iloc[:,:1]
y.head()
# Out:
#     price
# 0  221900
# 1  538000
# 2  180000
# 3  604000
# 4  510000

# %%
x=dataset.iloc[:,1:2]
x.head()
# Out:
#    sqft_living
# 0         1180
# 1         2570
# 2          770
# 3         1960
# 4         1680

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %% [raw]
# ## Training the Model

# %%
from sklearn.linear_model import LinearRegression
lin_reg=LinearRegression()

# %%
lin_reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [raw]
# ## Testing the Model

# %%
y_pred=lin_reg.predict(x_test)
y_pred
# Out:
# array([[ 360116.30918286],
#        [1261900.99730684],
#        [ 362899.59525731],
#        ...,
#        [ 560512.90654374],
#        [ 374032.73955514],
#        [ 329500.16236383]])

# %% [raw]
# ## Calculating Persormance Metrix of the Model Made

# %%
from sklearn.metrics import r2_score,mean_squared_error
RMSE=np.sqrt(mean_squared_error(y_test,ypred))
r_square=r2_score(y_test,ypred)
print("Root mean square error is......",RMSE)
print("r square value is......",r_square)
# Out:
# Root mean square error is...... 264896.2296616816
# r square value is...... 0.488899283822523

# %% [raw]
# ##  Inferences
#
# A) R-square value is 0.48 suggesting that only about 48% of the variance in the target variable i.e. price can be explained by the independent variable area of living.
#
# B) Root mean square error is very high for the model suggesting that a large error exist in between the predicted value and the actual values of the target variable (price).
#
# Not a good regression fit

# %% [raw]
# ##  Model 2

# %% [raw]
# ## Price as dependent variable and number of bedrooms as independent variable. Since both the varbiarbles are continuous a simple linear regression model is used.

# %% [raw]
# ## Splitting the dataset into training and testing data

# %%
x1=dataset.iloc[:,2:3]
x1.head()
# Out:
#    bedrooms
# 0         3
# 1         3
# 2         2
# 3         4
# 4         3

# %%
from sklearn.model_selection import train_test_split
x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y,test_size=0.3,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
lin_reg1=LinearRegression()

# %%
lin_reg1.fit(x1_train,y1_train)
# Out:
# LinearRegression()

# %%
y_pred1=lin_reg1.predict(x1_test)
y_pred1
# Out:
# array([[609985.5089382 ],
#        [495500.22465829],
#        [381014.94037837],
#        ...,
#        [381014.94037837],
#        [724470.79321811],
#        [609985.5089382 ]])

# %%
from sklearn.metrics import r2_score,mean_squared_error
print("The R-Square value is.......",r2_score(y1_test,y_pred1))
print("The RMSE value is.......",np.sqrt(mean_squared_error(y1_test,y_pred1)))
# Out:
# The R-Square value is....... 0.1004787075970095
# The RMSE value is....... 374684.6359495246

# %% [raw]
# ##Inferences
#
# A) R-square value is 0.10 suggesting that only about 10% of the variance in the target variable i.e. price can be explained by the independent variable number of bedrooms.
#
# B) Root mean square error is very high for the model suggesting that a large error exist in between the predicted value and the actual values of the target variable (price).
#
# This Model is Not a good regression fit

# %% [raw]
# ## Model 3

# %% [raw]
# ##  Price as dependent variable and number of bathrooms as independent variable. Since both the varbiarbles are continuous a
#     simple linear regression model is used.

# %%
x2=dataset.iloc[:,3:4]
x2.head()
# Out:
#    bathrooms
# 0       1.00
# 1       2.25
# 2       1.00
# 3       3.00
# 4       2.00

# %%
from sklearn.model_selection import train_test_split
x2_train,x2_test,y2_train,y2_test=train_test_split(x2,y,test_size=0.3,random_state=2)

# %%
from sklearn.linear_model import LinearRegression
lin_reg2=LinearRegression()

# %%
lin_reg2.fit(x2_train,y2_train)
# Out:
# LinearRegression()

# %%
y_pred2=lin_reg1.predict(x2_test)
y_pred2
# Out:
# array([[409636.26144835],
#        [323772.29823842],
#        [266529.65609846],
#        ...,
#        [438257.58251833],
#        [409636.26144835],
#        [352393.61930839]])

# %%
from sklearn.metrics import r2_score,mean_squared_error
print("The R-Square value is.......",r2_score(y2_test,y_pred2))
print("The RMSE value is.......",np.sqrt(mean_squared_error(y2_test,y_pred2)))
# Out:
# The R-Square value is....... 0.043037127688894006
# The RMSE value is....... 365145.11746093485

# %% [raw]
# ##  Inferences
#
# A) R-square value is 0.04 suggesting that only about 4% of the variance in the target variable i.e. price can be explained by the independent variable number of bathrooms.
#
# B) Root mean square error is very high for the model suggesting that a large error exist in between the predicted value and the actual values of the target variable (price).
#
# This Model is also Not a good regression fit

# %% [raw]
# ## Model 4

# %% [raw]
# ##  Price as dependent variable and number of floors as independent variable. Since both the varbiarbles are continuous a simple
#     linear regression model is used.

# %%
x3=dataset.iloc[:,4:]
x3.head()
# Out:
#    floors
# 0     1.0
# 1     2.0
# 2     1.0
# 3     1.0
# 4     1.0

# %%
from sklearn.model_selection import train_test_split
x3_train,x3_test,y3_train,y3_test=train_test_split(x3,y,test_size=0.3,random_state=3)

# %%
from sklearn.linear_model import LinearRegression
lin_reg3=LinearRegression()

# %%
lin_reg3.fit(x3_train,y3_train)
# Out:
# LinearRegression()

# %%
y_pred3=lin_reg3.predict(x3_test)
y_pred3
# Out:
# array([[452432.3492184 ],
#        [626942.29245276],
#        [626942.29245276],
#        ...,
#        [452432.3492184 ],
#        [452432.3492184 ],
#        [452432.3492184 ]])

# %%
from sklearn.metrics import r2_score,mean_squared_error
print("The R-Square value is.......",r2_score(y3_test,y_pred3))
print("The RMSE value is.......",np.sqrt(mean_squared_error(y3_test,y_pred3)))
# Out:
# The R-Square value is....... 0.0660669800768724
# The RMSE value is....... 353816.49481193395

# %% [raw]
# ##  Inferences
#
# A) R-square value is 0.06 suggesting that only about 6% of the variance in the target variable i.e. price can be explained by the independent variable number of floors.
#
# B) Root mean square error is very high for the model suggesting that a large error exist in between the predicted value and the actual values of the target variable (price).
#
# This Model is Not a good regression fit

# %% [raw]
# ## Model 5

# %% [raw]
# ##  Price as dependent variable and area of living in square feet, number of bedrooms,number of bathrooms and number of floors
#     as independent variables. Since all the varbiarbles are continuous a munltiple linear regression model is used.

# %%
x4=dataset.iloc[:,1:5]
x4.head()
# Out:
#    sqft_living  bedrooms  bathrooms  floors
# 0         1180         3       1.00     1.0
# 1         2570         3       2.25     2.0
# 2          770         2       1.00     1.0
# 3         1960         4       3.00     1.0
# 4         1680         3       2.00     1.0

# %%
from sklearn.model_selection import train_test_split
x4_train,x4_test,y4_train,y4_test=train_test_split(x4,y,test_size=0.3,random_state=4)

# %%
from sklearn.linear_model import LinearRegression
lin_reg4=LinearRegression()

# %%
lin_reg4.fit(x4_train,y4_train)
# Out:
# LinearRegression()

# %%
y_pred4=lin_reg4.predict(x4_test)
y_pred4
# Out:
# array([[520451.76087349],
#        [605591.59004239],
#        [412322.00294392],
#        ...,
#        [536017.4477493 ],
#        [322835.93706476],
#        [735091.72319132]])

# %%
from sklearn.metrics import r2_score,mean_squared_error
print("The R-Square value is.......",r2_score(y4_test,y_pred4))
print("The RMSE value is.......",np.sqrt(mean_squared_error(y4_test,y_pred4)))
# Out:
# The R-Square value is....... 0.5005924823648306
# The RMSE value is....... 259396.1436572631

# %% [raw]
# ##  Inferences
#
# A) R-square value is 0.5 suggesting that only about 50% or half of the variance in the target variable i.e. price can be explained by the independent variables area of living, number of bedrooms,number of bathrooms and number of floors.
#
# B) Root mean square error is very high for the model suggesting that a large error exist in between the predicted value and the actual values of the target variable (price).
#
# This Model is Not a good regression fit
